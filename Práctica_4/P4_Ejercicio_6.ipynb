# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-lorenzo/Termodinamica/blob/master/Pr%C3%A1ctica_4/P4_Ejercicio_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problema 6
# Mediante un eje que acciona una rueda de paletas se entrega trabajo al aire contenido en B hasta que este alcanza los 500°C. Determinar el trabajo suministrado por el eje.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Solución

# %%
# Datos:
P_A = 9e5          # [Pa]        (presíon en A)
x_Ai = 1           #             (títilo en A)
T_f = 500 + 273.15 # [K]         (temperatura final)
m_A = 10           # [kg]        (masa en A)
m_B = 30           # [kg]        (masa en B)
P_Bi = 1e5         # [Pa]        (presión inicial en B)
cv = 0.7176e3      # [J/(kg·K)]  (constante cv del aire)

# %%
# De tabla
v_Ai = 0.2148          # [m^3/kg]  (volumen específico inicial en A)
u_Ai = 2578.81e3       # [J/kg]    (energ. interna esp. inicial en A)
T_Ai = 175.36 + 273.15 # [K]       (temperatura inicial en A)
T_Bi = T_Ai            #           (temperatura inicial en B)

v_Af = 0.39361         # [m^3/kg]  (volumen específico final en A)
u_Af = 3125.13e3       # [J/kg]    (energ. interna esp. final en A)

# %%
# Volumen inicial en A
V_Ai = m_A*v_Ai
# Volumen final en A
V_Af = m_A*v_Af
# Variación de volumen en A
ΔV_A = V_Af - V_Ai
# Variación de energía interna en A
ΔU_A = m_A*(u_Af - u_Ai)
# Variación de energían interna en B
ΔU_B = m_B*cv*(T_f - T_Bi)

# %% [markdown]
# Planteando la ecuación del primer principio, se tiene que

# %% [markdown]
# $$Q = \Delta U + W_{\Delta V} + W_{eje}$$

# %% [markdown]
# $$0 = \Delta U_A + \Delta U_B + P \Delta V_A + W_{eje}$$

# %% [markdown]
# Entonces
# $$W_{eje} = -\Delta U_A - \Delta U_B - P \Delta V_A$$

# %%
# Trabajo en el eje
W_eje = -ΔU_A - ΔU_B - P_A*ΔV_A

# %%
#@title Trabajo en el eje
print("W_eje = %.2f [kJ]"%(W_eje/1000))
# Out:
# W_eje = -14061.34 [kJ]
