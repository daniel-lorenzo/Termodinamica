# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-lorenzo/Termodinamica/blob/master/Pr%C3%A1ctica_5/P5_Ejercicio_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 7
# Para el siguiente proceso determinar:
# 1. Estado del vapor en el punto 2 (P, t y X)
# 2. W entregado por la turbina
# 3. Caudal másico de vapor m
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Solución

# %%
# Datos:
P_1 = 100e5 # [Pa]
T_1 = 450 + 273.15 # [K]
P_2 = 40e5 # [Pa]
P_3 = 1.4e5 # [Pa]
T_3 = 190 + 273.15 # [K]
P_4 = 1.3e5 # [Pa]
T_4 = 130 + 273.15 # [K]
m_5 = 8 # [kg/s]
P_5 = 1e5 # [Pa]
T_5 = 20 + 273.15 # [K]
P_6 = 1e5 # [Pa]
T_6 = 60 + 273.15 # [K]

# %% [markdown]
# $$h_1 = h_2$$

# %%
# De tabla
h_1 = 3243.64e3 # [J/kg]      (con P_1 = 100 bar y T_1 = 450°C)

# %%
h_2 = h_1
T_2 = 411.97 + 273.15 # [K]  (de tabla, interpolando)

# %% [markdown]
# ### 1) Estado de vapor en 2
# No existe $x_2$
# P = 40 bar
# T = 411,97°C

# %% [markdown]
# ---
# ### 2) Trabajo entregado por la turbina

# %% [markdown]
# $$-W = \Delta H$$

# %% [markdown]
# $$-W = \dot{m}_2 (h_3 - h_2)$$

# %% [markdown]
# $$W = \dot{m}_2 (h_2 - h_3)$$

# %%
h_3 = 2853.46e3 # [J/kg]    (con P=1.4 bar y t=190°C)

# %% [markdown]
# Intercambiador de calor
# $$m_3 h_3 - m_4 h_4 = m_6 h_6 - m_5 h_5$$

# %% [markdown]
# $m_3 = m_4$
# $m_5 = m_6$
# $$m_3(h_3 - h_4) = m_5 (h_6 - h_5)$$

# %% [markdown]
# $$m_3 = \frac{m_5 (h_6 - h_5)}{h_3 - h_4}$$

# %%
h_4 = 2733.66e3 # [J/kg]   (con P=1.3 bar y t=130°C)
h_5 =   83.95e3 # [J/kg]   (con P=1 bar y t=20°C)
h_6 =  251.16e3 # [J/kg]   (con P=1 bar y t=60°C)
m_5 =  8 # [kg/s]

# %%
# Calculo de caudal másico de vapor
m_3 = m_5*(h_6 - h_5)/(h_3 - h_4)

# %%
m_1 = m_2 = m_3
# Cálculo de trabajo de la turbina
W = m_2*(h_2 - h_3)

# %%
#@title Resultados
print("Caudal másico de vapor")
print("m = %.2f [kg/s]"%m_1)
print("Trabajo entregado por la turbina")
print("W = %.2f [kW]"%(W/1000))
# Out:
# Caudal másico de vapor
# m = 11.17 [kg/s]
# Trabajo entregado por la turbina
# W = 4356.73 [kW]
